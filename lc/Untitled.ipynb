# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv(r"C:\Users\Alexandre\Desktop\teste_edesoft\BackEnd\lc\arquivos\arquivo_exemplo.csv", sep=';', encoding = "ISO-8859-1")

# %%
df
# Out:
#                 Originador      Doc Originador                Cedente  \
# 0   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 1   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 2   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 3   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 4   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 5   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 6   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 7   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 8   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 9   EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 10  EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# 11  EMPIRICA INVESTIMENTOS  10.896.871/0001-99  EMPIRICA HOLDING S.A.
# ...

# %%
df.Id.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Id, dtype: bool

# %%
df['Data de Emissão'] = pd.to_datetime(df['Data de Emissão'])
df['Data de Vencimento'] = pd.to_datetime(df['Data de Vencimento'])
df['Data de Compra CCB'] = pd.to_datetime(df['Data de Compra CCB'])
# Out:
# C:\Users\Alexandre\AppData\Local\Temp\ipykernel_27512\251031280.py:2: UserWarning: Parsing '14/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Data de Vencimento'] = pd.to_datetime(df['Data de Vencimento'])
# C:\Users\Alexandre\AppData\Local\Temp\ipykernel_27512\251031280.py:2: UserWarning: Parsing '14/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Data de Vencimento'] = pd.to_datetime(df['Data de Vencimento'])
# C:\Users\Alexandre\AppData\Local\Temp\ipykernel_27512\251031280.py:2: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Data de Vencimento'] = pd.to_datetime(df['Data de Vencimento'])
# ...

# %%
df['Parcela R$'].str.replace(',', '.').str.replace(r'[^\d.]+', '', regex=True).astype(float)
# Out:
# 0       17.87
# 1       17.87
# 2       17.87
# 3       17.87
# 4       17.87
# 5       17.87
# 6       17.87
# 7       18.51
# 8       81.27
# 9       81.27
# 10      81.27
# 11      81.27
# 12      81.27
# 13      81.27
# 14      81.27
# 15      84.02
# 16     666.45
# 17     666.45
# 18     666.45
# 19     666.45
# 20     666.45
# 21     835.23
# 22    1776.39
# 23    1776.39
# 24    1776.39
# 25    1776.39
# 26    1776.39
# 27    1776.39
# 28    1776.39
# 29    1776.39
# 30    1776.39
# 31    2125.65
# Name: Parcela R$, dtype: float64

# %%
df['IOF R$'].str.replace(',', '.').astype(float)
df['Valor do Empréstimo'].str.replace(',', '.').astype(float)
df['Taxa de Juros (a.m.)'].str.replace(',', '.').astype(float)
df['Parcela R$'].str.replace(',', '.').astype(float)
df['Principal R$'].str.replace(',', '.').astype(float)
df['Juros R$'].str.replace(',', '.').astype(float)
df['Comissão R$'].str.replace(',', '.').astype(float)
# Out:
# 0       1.20
# 1       1.20
# 2       1.20
# 3       1.20
# 4       1.20
# 5       1.20
# 6       1.20
# 7       1.20
# 8       5.49
# 9       5.49
# 10      5.49
# 11      5.49
# 12      5.49
# 13      5.49
# 14      5.49
# 15      5.49
# 16     26.28
# 17     26.28
# 18     26.28
# 19     26.28
# 20     26.28
# 21     26.28
# 22    160.73
# 23    160.73
# 24    160.73
# 25    160.73
# 26    160.73
# 27    160.73
# 28    160.73
# 29    160.73
# 30    160.73
# 31    160.73
# Name: IOF R$, dtype: float64
